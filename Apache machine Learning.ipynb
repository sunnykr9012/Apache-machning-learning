# %%
# !pip install pyspark

# %%
from pyspark.sql import SparkSession
spark=(SparkSession
.builder
.appName("sunny")
.getOrCreate())

# %%
sc=spark.sparkContext
sqlContext=spark

# %%
import pyspark.ml

# %%
from pyspark.ml.feature import Binarizer

# %%
#data types
#local vectors
import numpy as np
import scipy.sparse as sps
from pyspark.mllib.linalg import Vectors
#array a numpy array as a dense vector.
dv1=np.array([1.1,0.0,3.0])
dv1
#use a python list as a dense vectors 
dv2=[1.0,0.0,3.0]
dv2
#create a sparsevectors
sv1=Vectors.sparse(3,[0,2],[1.0,3.0])
sv1
#use a single-colunm scipy csc_maxtrix as a sparse vsctors
sv2=sps.csc_matrix((np.array([1.0,3.0]),np.array([0,2]),np.array([0,2])),shape=(3,1))
sv2
# Out:
# <3x1 sparse matrix of type '<class 'numpy.float64'>'
# 	with 2 stored elements in Compressed Sparse Column format>

# %%
#labled point
from pyspark.mllib.linalg import SparseVector
from pyspark.mllib.regression import LabeledPoint

#create a labeled point with a positive lable and a dense feature vector
pos=LabeledPoint(1.0,[1.0,0.0,3.0])
pos
# Out:
# LabeledPoint(1.0, [1.0,0.0,3.0])

# %%
#create a labeled point with a negative lable and a dense feature vector
neg=LabeledPoint(0.0,SparseVector(3,[0,2],[1.0,3.0]))
neg
# Out:
# LabeledPoint(0.0, (3,[0,2],[1.0,3.0]))

# %%
from datetime import datetime
from pyspark.sql import Row 
spark=SparkSession(sc)
allTypes=sc.parallelize([Row(i=1,s="string",d=1.0,l=1,
    b=True,list=[1,2,3],dict={"s":0},row=Row(a=1),
    time=datetime(2014,8,1,14,1,5))])
df=allTypes.toDF()
df.createOrReplaceTempView("allTypes")
spark.sql('select i+1, d+1, not b, list[1],dict["s"],time,row.a '
           'from allTypes where b and i > 0').collect()
# Out:
# ---------------------------------------------------------------------------
# Py4JJavaError                             Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_9720\775068163.py in <module>
#       5     b=True,list=[1,2,3],dict={"s":0},row=Row(a=1),
#       6     time=datetime(2014,8,1,14,1,5))])
# ----> 7 df=allTypes.toDF()
#       8 df.createOrReplaceTempView("allTypes")
#       9 spark.sql('select i+1, d+1, not b, list[1],dict["s"],time,row.a '
#
# ~\anaconda3\lib\site-packages\pyspark\sql\session.py in toDF(self, schema, sampleRatio)
#     100         [Row(name='Alice', age=1)]
#     101         """
# --> 102         return sparkSession.createDataFrame(self, schema, sampleRatio)
#     103
#     104     RDD.toDF = toDF  # type: ignore[assignment]
#
# ~\anaconda3\lib\site-packages\pyspark\sql\session.py in createDataFrame(self, data, schema, samplingRatio, verifySchema)
#     892                 data, schema, samplingRatio, verifySchema
# ...

# %%
from pyspark.sql.functions import col, count, lit, max
from pyspark.sql import Observation
df=spark.createDataFrame([["Alice", 2], ["Bob", 5]], ["name","age"])
observation=Observation("my metrics")
observed_df=df.observe(observation, count(lit(1)).alias("count"),max(col("age")))
observed_df.count()
2
observation.get
{'count':2, 'max(age)':5}
# Out:
# ---------------------------------------------------------------------------
# Py4JJavaError                             Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_9720\3007757394.py in <module>
#       4 observation=Observation("my metrics")
#       5 observed_df=df.observe(observation, count(lit(1)).alias("count"),max(col("age")))
# ----> 6 observed_df.count()
#       7 2
#       8 observation.get
#
# ~\anaconda3\lib\site-packages\pyspark\sql\dataframe.py in count(self)
#     802         2
#     803         """
# --> 804         return int(self._jdf.count())
#     805
#     806     def collect(self) -> List[Row]:
#
# ~\anaconda3\lib\site-packages\py4j\java_gateway.py in __call__(self, *args)
#    1319
#    1320         answer = self.gateway_client.send_command(command)
# -> 1321         return_value = get_return_value(
#    1322             answer, self.gateway_client, self.target_id, self.name)
#    1323
#
# ...

# %%
row=Row(name="Alice", age=11)
row
Row(name='Alice',age=11)
row['name'],row['age']
('Alice',11)
row.name, row.age
('Alice',11)
'name' in row
True
'wrong_key' in row
False

# %%
#@title Default title text
from pyspark.ml.linalg import Vectors
from pyspark.ml.stat import Correlation
data=[(Vectors.sparse(4,[(0,1.0),(3,-2.0)]),),
      (Vectors.dense([4.0,5.0,0.0,3.0]),),
      (Vectors.dense([6.0,7.0,0.0,8.0]),),
      (Vectors.sparse(4,[(0,9.0),(3,1.0)]),)]
df=spark.createDataFrame(data,["features"])

r1=Correlation.corr(df,"features").head()

print("Person correlation matrix:\n"+str(r1[0]))
r2=Correlation.corr(df,"features","spearman").head()

print("Spearman correlation matrix:\n"+str(r2[0]))

# %%
from pyspark.ml.feature import FeatureHasher
dataset=spark.createDataFrame([
    (2.2, True,"1","foo"),
    (2.2, False,"2","bar"),
    (2.2, False,"3","baz"),
    (2.2, False,"4","foo")
],["real","bool","stringNum","string"])
hasher=FeatureHasher(inputCols=["real","bool","stringNum","string"],
                     outputCol="Feature")
featurized=hasher.transform(dataset)
featurized.show(truncate=False)
# Out:
# ---------------------------------------------------------------------------
# Py4JJavaError                             Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_9720\1630515466.py in <module>
#       9                      outputCol="Feature")
#      10 featurized=hasher.transform(dataset)
# ---> 11 featurized.show(truncate=False)
#
# ~\anaconda3\lib\site-packages\pyspark\sql\dataframe.py in show(self, n, truncate, vertical)
#     613                 )
#     614
# --> 615             print(self._jdf.showString(n, int_truncate, vertical))
#     616
#     617     def __repr__(self) -> str:
#
# ~\anaconda3\lib\site-packages\py4j\java_gateway.py in __call__(self, *args)
#    1319
#    1320         answer = self.gateway_client.send_command(command)
# -> 1321         return_value = get_return_value(
#    1322             answer, self.gateway_client, self.target_id, self.name)
#    1323
#
# ~\anaconda3\lib\site-packages\pyspark\sql\utils.py in deco(*a, **kw)
# ...

# %%
from pyspark.ml.feature import Tokenizer, RegexTokenizer
from pyspark.sql.functions import col, udf
from pyspark.sql.types import IntegerType

sentenceDataFrame=spark.createDataFrame([
    (0," Hi heared about spark"),
    (1,"I wish Java could use case classes"),
    (2,"Logistic, regression, models,are,meat")

],["id","sentence"])

tokenizer=Tokenizer(inputCol="sentence", outputCol="words")

regexTokenizer=RegexTokenizer(inputCol="sentence", outputCol="words",pattern="\\w")

countTokens=udf(lambda words: len(words), IntegerType())

tokenized=tokenizer.transform(sentenceDataFrame)
tokenized.select("sentence","words")\
    .withColumn("tokens",countTokens(col("words"))).show(truncate=False)

regexTokenized=regexTokenizer.transform(sentenceDataFrame)
regexTokenized.select("sentence","words")\
    .withColumn("tokens",countTokens(col("words"))).show(truncate=False)
